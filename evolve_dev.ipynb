# %% [markdown]
# # Evolve - evolution simulation
#
# A much simplified version of this rad thing I saw on YouTube [I programed some creatures. They Evolved.](https://youtu.be/N3tRFayqVtk)
#
# Blobs are created with some combination of senses and actions. Blobs may sense and move up, down, left and right. Blobs also have a multi-layer perceptron brain to process input signals to action signals. All of these attributes are determined by an 8-bit ingeger assigned at birth.
#
# When mating, the new Blob will inherit half of it's genes from each parent.
#
# Blobs are periodically trained to respond more strongly to higher concentrations of Blobs nearby.
#
# Blobs only find each other and mate. They have no other abilities or drives.
#
# We create a square grid, Blobland, to host a population Blobs. After so many steps of moving around and mating, all Blobs not in the safe zone are killed. The remaining are dispersed throughout Blobland, and new Blobs are added to replenish the population to the initial setting.
#
# As each epoch completes, statistics about survival and mating opportunities are printed.
#
# After the chosen number of epoch completes an animation of each epoch may be viewed, along with a histogram relating genetic diversity of the surviving blobs.
#
# Use the slider, rather than the play button, for smooth animations.
#
# **If a simulation seems to be going nowhere, you can stop with the stop button above and still view an animation of completed epochs**

# %% [markdown]
# ## Settings in settings.py:
#  - GENERATIONS
#      - How many generations blobs live
#  - STEPS_PER_WORLD_GENERATION
#      - How many steps blobs get to take per generation
#  - SCENARIO
#      - The location of the safe zone, if a blob makes it here it survies to the next generation
#  - SAFE_ZONE_SIZE
#      - How large is the safe zone
#  - INITIAL_POPULATION
#      - Minimum number of blobs to start each generation with
#          - Randomly created blobs fill in if the number of surviving blobs is below the initial population
#  - OVER_POPULATION_STRATEGY
#       - Keep a random sample of survivors, or keep the oldest survivors

# %%
from evolve.main import main

# %%
blobland = main()
# Out:
# EPOCH: 1	epoch time 2 seconds
# surviving population 25	peak population 100	epoch peak 100	surviving proportion 0.25
# repeats 0	total mated 1	surviving gene pool 22
# oldest survivor 1	Ultimate fucker 1	total mutants 0
#
# EPOCH: 2	epoch time 3 seconds
# surviving population 56	peak population 140	epoch peak 140	surviving proportion 0.40
# repeats 10	total mated 12	surviving gene pool 32
# oldest survivor 2	Ultimate fucker 7	total mutants 0
# /home/llpk/projects/evolve/evolve/brain.py:27: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# EPOCH: 3	epoch time 4 seconds
# surviving population 55	peak population 147	epoch peak 147	surviving proportion 0.37
# repeats 24	total mated 18	surviving gene pool 31
# oldest survivor 3	Ultimate fucker 11	total mutants 0
#
# EPOCH: 4	epoch time 4 seconds
# surviving population 39	peak population 147	epoch peak 136	surviving proportion 0.29
# repeats 18	total mated 15	surviving gene pool 23
# oldest survivor 4	Ultimate fucker 12	total mutants 0
#
# EPOCH: 5	epoch time 3 seconds
# surviving population 55	peak population 147	epoch peak 145	surviving proportion 0.38
# repeats 18	total mated 20	surviving gene pool 31
# oldest survivor 5	Ultimate fucker 12	total mutants 0
#
# EPOCH: 6	epoch time 3 seconds
# surviving population 71	peak population 172	epoch peak 172	surviving proportion 0.41
# repeats 24	total mated 22	surviving gene pool 35
# oldest survivor 6	Ultimate fucker 12	total mutants 1
#
# EPOCH: 7	epoch time 4 seconds
# surviving population 92	peak population 193	epoch peak 193	surviving proportion 0.48
# repeats 32	total mated 34	surviving gene pool 38
# oldest survivor 7	Ultimate fucker 18	total mutants 0
#
# EPOCH: 8	epoch time 5 seconds
# surviving population 96	peak population 193	epoch peak 187	surviving proportion 0.51
# repeats 34	total mated 34	surviving gene pool 32
# oldest survivor 7	Ultimate fucker 14	total mutants 0
#
# EPOCH: 9	epoch time 5 seconds
# surviving population 122	peak population 243	epoch peak 243	surviving proportion 0.50
# repeats 47	total mated 45	surviving gene pool 33
# oldest survivor 6	Ultimate fucker 16	total mutants 0
#
# EPOCH: 10	epoch time 6 seconds
# surviving population 163	peak population 290	epoch peak 290	surviving proportion 0.56
# repeats 60	total mated 70	surviving gene pool 38
# oldest survivor 7	Ultimate fucker 15	total mutants 1
#
# EPOCH: 11	epoch time 8 seconds
# surviving population 248	peak population 444	epoch peak 444	surviving proportion 0.56
# repeats 69	total mated 96	surviving gene pool 41
# oldest survivor 8	Ultimate fucker 20	total mutants 2
#
# EPOCH: 12	epoch time 10 seconds
# surviving population 280	peak population 548	epoch peak 548	surviving proportion 0.51
# repeats 73	total mated 100	surviving gene pool 36
# oldest survivor 7	Ultimate fucker 24	total mutants 0
#
# EPOCH: 13	epoch time 9 seconds
# surviving population 277	peak population 566	epoch peak 566	surviving proportion 0.49
# repeats 77	total mated 102	surviving gene pool 34
# oldest survivor 8	Ultimate fucker 28	total mutants 3
#
# EPOCH: 14	epoch time 9 seconds
# surviving population 308	peak population 575	epoch peak 575	surviving proportion 0.54
# repeats 90	total mated 114	surviving gene pool 29
# oldest survivor 9	Ultimate fucker 30	total mutants 2
#
# EPOCH: 15	epoch time 9 seconds
# surviving population 340	peak population 616	epoch peak 616	surviving proportion 0.55
# repeats 103	total mated 128	surviving gene pool 25
# oldest survivor 10	Ultimate fucker 36	total mutants 0
#
# EPOCH: 16	epoch time 9 seconds
# surviving population 336	peak population 616	epoch peak 615	surviving proportion 0.55
# repeats 100	total mated 126	surviving gene pool 21
# oldest survivor 7	Ultimate fucker 19	total mutants 1
#
# EPOCH: 17	epoch time 9 seconds
# surviving population 333	peak population 647	epoch peak 647	surviving proportion 0.51
# repeats 100	total mated 128	surviving gene pool 18
# oldest survivor 6	Ultimate fucker 20	total mutants 1
#
# EPOCH: 18	epoch time 9 seconds
# surviving population 403	peak population 707	epoch peak 707	surviving proportion 0.57
# repeats 115	total mated 158	surviving gene pool 18
# oldest survivor 5	Ultimate fucker 18	total mutants 2
#
# EPOCH: 19	epoch time 8 seconds
# surviving population 292	peak population 707	epoch peak 570	surviving proportion 0.51
# repeats 89	total mated 113	surviving gene pool 14
# oldest survivor 6	Ultimate fucker 13	total mutants 2
#
# EPOCH: 20	epoch time 8 seconds
# surviving population 355	peak population 707	epoch peak 633	surviving proportion 0.56
# repeats 107	total mated 145	surviving gene pool 12
# oldest survivor 6	Ultimate fucker 20	total mutants 0
#
# EPOCH: 21	epoch time 8 seconds
# surviving population 365	peak population 707	epoch peak 597	surviving proportion 0.61
# repeats 93	total mated 135	surviving gene pool 9
# oldest survivor 5	Ultimate fucker 21	total mutants 0
#
# EPOCH: 22	epoch time 8 seconds
# surviving population 328	peak population 707	epoch peak 556	surviving proportion 0.59
# repeats 89	total mated 118	surviving gene pool 11
# oldest survivor 4	Ultimate fucker 16	total mutants 1
#
# EPOCH: 23	epoch time 8 seconds
# surviving population 343	peak population 707	epoch peak 562	surviving proportion 0.61
# repeats 92	total mated 123	surviving gene pool 9
# oldest survivor 5	Ultimate fucker 20	total mutants 0
#
# EPOCH: 24	epoch time 9 seconds
# surviving population 353	peak population 707	epoch peak 581	surviving proportion 0.61
# repeats 94	total mated 129	surviving gene pool 11
# oldest survivor 6	Ultimate fucker 14	total mutants 1
#
# EPOCH: 25	epoch time 9 seconds
# surviving population 385	peak population 707	epoch peak 687	surviving proportion 0.56
# repeats 108	total mated 146	surviving gene pool 12
# oldest survivor 5	Ultimate fucker 15	total mutants 3
#
# EPOCH: 26	epoch time 9 seconds
# surviving population 355	peak population 707	epoch peak 651	surviving proportion 0.55
# repeats 92	total mated 130	surviving gene pool 11
# oldest survivor 6	Ultimate fucker 18	total mutants 3
#
# EPOCH: 27	epoch time 9 seconds
# surviving population 400	peak population 707	epoch peak 654	surviving proportion 0.61
# repeats 112	total mated 150	surviving gene pool 11
# oldest survivor 6	Ultimate fucker 20	total mutants 1
#
# EPOCH: 28	epoch time 9 seconds
# surviving population 388	peak population 707	epoch peak 674	surviving proportion 0.58
# repeats 107	total mated 140	surviving gene pool 7
# oldest survivor 7	Ultimate fucker 24	total mutants 0
#
# EPOCH: 29	epoch time 9 seconds
# surviving population 404	peak population 707	epoch peak 636	surviving proportion 0.64
# repeats 114	total mated 157	surviving gene pool 8
# oldest survivor 8	Ultimate fucker 25	total mutants 2
#
# EPOCH: 30	epoch time 8 seconds
# surviving population 367	peak population 707	epoch peak 653	surviving proportion 0.56
# repeats 107	total mated 142	surviving gene pool 8
# oldest survivor 9	Ultimate fucker 26	total mutants 2
#
# EPOCH: 31	epoch time 8 seconds
# surviving population 367	peak population 707	epoch peak 610	surviving proportion 0.60
# repeats 103	total mated 138	surviving gene pool 8
# oldest survivor 10	Ultimate fucker 27	total mutants 0
#
# EPOCH: 32	epoch time 9 seconds
# surviving population 385	peak population 707	epoch peak 640	surviving proportion 0.60
# repeats 105	total mated 144	surviving gene pool 9
# oldest survivor 5	Ultimate fucker 17	total mutants 1
#
# EPOCH: 33	epoch time 9 seconds
# surviving population 346	peak population 707	epoch peak 637	surviving proportion 0.54
# repeats 99	total mated 125	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 21	total mutants 1
#
# EPOCH: 34	epoch time 8 seconds
# surviving population 372	peak population 707	epoch peak 605	surviving proportion 0.61
# repeats 108	total mated 142	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 20	total mutants 1
#
# EPOCH: 35	epoch time 9 seconds
# surviving population 379	peak population 707	epoch peak 650	surviving proportion 0.58
# repeats 108	total mated 151	surviving gene pool 7
# oldest survivor 6	Ultimate fucker 23	total mutants 2
#
# EPOCH: 36	epoch time 9 seconds
# surviving population 401	peak population 707	epoch peak 641	surviving proportion 0.63
# repeats 105	total mated 147	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 28	total mutants 2
#
# EPOCH: 37	epoch time 8 seconds
# surviving population 340	peak population 707	epoch peak 606	surviving proportion 0.56
# repeats 92	total mated 125	surviving gene pool 10
# oldest survivor 6	Ultimate fucker 20	total mutants 3
#
# EPOCH: 38	epoch time 9 seconds
# surviving population 409	peak population 707	epoch peak 653	surviving proportion 0.63
# repeats 114	total mated 159	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 25	total mutants 1
#
# EPOCH: 39	epoch time 9 seconds
# surviving population 436	peak population 707	epoch peak 664	surviving proportion 0.66
# repeats 117	total mated 163	surviving gene pool 8
# oldest survivor 7	Ultimate fucker 19	total mutants 0
#
# EPOCH: 40	epoch time 8 seconds
# surviving population 362	peak population 707	epoch peak 610	surviving proportion 0.59
# repeats 96	total mated 128	surviving gene pool 6
# oldest survivor 4	Ultimate fucker 18	total mutants 0
#
# EPOCH: 41	epoch time 9 seconds
# surviving population 397	peak population 707	epoch peak 668	surviving proportion 0.59
# repeats 110	total mated 149	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 22	total mutants 2
#
# EPOCH: 42	epoch time 8 seconds
# surviving population 392	peak population 707	epoch peak 661	surviving proportion 0.59
# repeats 109	total mated 150	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 21	total mutants 2
#
# EPOCH: 43	epoch time 9 seconds
# surviving population 386	peak population 707	epoch peak 604	surviving proportion 0.64
# repeats 111	total mated 145	surviving gene pool 7
# oldest survivor 6	Ultimate fucker 25	total mutants 0
#
# EPOCH: 44	epoch time 8 seconds
# surviving population 360	peak population 707	epoch peak 590	surviving proportion 0.61
# repeats 92	total mated 128	surviving gene pool 8
# oldest survivor 7	Ultimate fucker 19	total mutants 2
#
# EPOCH: 45	epoch time 9 seconds
# surviving population 424	peak population 707	epoch peak 664	surviving proportion 0.64
# repeats 113	total mated 157	surviving gene pool 8
# oldest survivor 8	Ultimate fucker 22	total mutants 4
#
# EPOCH: 46	epoch time 8 seconds
# surviving population 365	peak population 707	epoch peak 582	surviving proportion 0.63
# repeats 107	total mated 140	surviving gene pool 9
# oldest survivor 6	Ultimate fucker 21	total mutants 2
#
# EPOCH: 47	epoch time 9 seconds
# surviving population 382	peak population 707	epoch peak 663	surviving proportion 0.58
# repeats 111	total mated 132	surviving gene pool 7
# oldest survivor 7	Ultimate fucker 22	total mutants 0
#
# EPOCH: 48	epoch time 9 seconds
# surviving population 396	peak population 707	epoch peak 690	surviving proportion 0.57
# repeats 128	total mated 154	surviving gene pool 6
# oldest survivor 6	Ultimate fucker 29	total mutants 0
#
# EPOCH: 49	epoch time 9 seconds
# surviving population 382	peak population 707	epoch peak 610	surviving proportion 0.63
# repeats 109	total mated 144	surviving gene pool 6
# oldest survivor 7	Ultimate fucker 21	total mutants 1
#
# EPOCH: 50	epoch time 9 seconds
# surviving population 407	peak population 707	epoch peak 663	surviving proportion 0.61
# repeats 108	total mated 148	surviving gene pool 6
# oldest survivor 6	Ultimate fucker 19	total mutants 1
#
# EPOCH: 51	epoch time 8 seconds
# surviving population 376	peak population 707	epoch peak 601	surviving proportion 0.63
# repeats 103	total mated 137	surviving gene pool 6
# oldest survivor 6	Ultimate fucker 21	total mutants 1
#
# EPOCH: 52	epoch time 9 seconds
# surviving population 335	peak population 707	epoch peak 563	surviving proportion 0.60
# repeats 109	total mated 129	surviving gene pool 6
# oldest survivor 7	Ultimate fucker 23	total mutants 0
#
# EPOCH: 53	epoch time 9 seconds
# surviving population 347	peak population 707	epoch peak 581	surviving proportion 0.60
# repeats 99	total mated 135	surviving gene pool 8
# oldest survivor 7	Ultimate fucker 19	total mutants 2
#
# EPOCH: 54	epoch time 9 seconds
# surviving population 363	peak population 707	epoch peak 598	surviving proportion 0.61
# repeats 104	total mated 133	surviving gene pool 7
# oldest survivor 8	Ultimate fucker 20	total mutants 1
#
# EPOCH: 55	epoch time 10 seconds
# surviving population 392	peak population 707	epoch peak 694	surviving proportion 0.56
# repeats 115	total mated 147	surviving gene pool 6
# oldest survivor 7	Ultimate fucker 21	total mutants 0
#
# EPOCH: 56	epoch time 9 seconds
# surviving population 365	peak population 707	epoch peak 625	surviving proportion 0.58
# repeats 112	total mated 133	surviving gene pool 7
# oldest survivor 8	Ultimate fucker 26	total mutants 2
#
# EPOCH: 57	epoch time 9 seconds
# surviving population 412	peak population 707	epoch peak 612	surviving proportion 0.67
# repeats 116	total mated 164	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 18	total mutants 1
#
# EPOCH: 58	epoch time 8 seconds
# surviving population 371	peak population 707	epoch peak 551	surviving proportion 0.67
# repeats 105	total mated 140	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 17	total mutants 1
#
# EPOCH: 59	epoch time 8 seconds
# surviving population 364	peak population 707	epoch peak 622	surviving proportion 0.59
# repeats 98	total mated 138	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 14	total mutants 1
#
# EPOCH: 60	epoch time 9 seconds
# surviving population 387	peak population 707	epoch peak 646	surviving proportion 0.60
# repeats 114	total mated 147	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 16	total mutants 3
#
# EPOCH: 61	epoch time 9 seconds
# surviving population 393	peak population 707	epoch peak 634	surviving proportion 0.62
# repeats 113	total mated 153	surviving gene pool 7
# oldest survivor 5	Ultimate fucker 19	total mutants 1
#
# EPOCH: 62	epoch time 8 seconds
# surviving population 371	peak population 707	epoch peak 600	surviving proportion 0.62
# repeats 101	total mated 145	surviving gene pool 4
# oldest survivor 5	Ultimate fucker 24	total mutants 0
#
# EPOCH: 63	epoch time 8 seconds
# surviving population 377	peak population 707	epoch peak 600	surviving proportion 0.63
# repeats 110	total mated 139	surviving gene pool 3
# oldest survivor 5	Ultimate fucker 18	total mutants 0
#
# EPOCH: 64	epoch time 9 seconds
# surviving population 404	peak population 707	epoch peak 685	surviving proportion 0.59
# repeats 121	total mated 155	surviving gene pool 4
# oldest survivor 5	Ultimate fucker 21	total mutants 1
#
# EPOCH: 65	epoch time 9 seconds
# surviving population 389	peak population 707	epoch peak 621	surviving proportion 0.63
# repeats 121	total mated 147	surviving gene pool 5
# oldest survivor 6	Ultimate fucker 16	total mutants 3
#
# EPOCH: 66	epoch time 8 seconds
# surviving population 359	peak population 707	epoch peak 565	surviving proportion 0.64
# repeats 103	total mated 136	surviving gene pool 5
# oldest survivor 6	Ultimate fucker 20	total mutants 1
#
# EPOCH: 67	epoch time 8 seconds
# surviving population 381	peak population 707	epoch peak 634	surviving proportion 0.60
# repeats 118	total mated 149	surviving gene pool 5
# oldest survivor 7	Ultimate fucker 22	total mutants 1
#
# EPOCH: 68	epoch time 9 seconds
# surviving population 351	peak population 707	epoch peak 583	surviving proportion 0.60
# repeats 104	total mated 125	surviving gene pool 4
# oldest survivor 8	Ultimate fucker 27	total mutants 0
#
# EPOCH: 69	epoch time 8 seconds
# surviving population 422	peak population 707	epoch peak 655	surviving proportion 0.64
# repeats 120	total mated 150	surviving gene pool 3
# oldest survivor 8	Ultimate fucker 30	total mutants 0
#
# EPOCH: 70	epoch time 8 seconds
# surviving population 408	peak population 707	epoch peak 614	surviving proportion 0.66
# repeats 109	total mated 153	surviving gene pool 3
# oldest survivor 9	Ultimate fucker 30	total mutants 1
#
# EPOCH: 71	epoch time 8 seconds
# surviving population 322	peak population 707	epoch peak 583	surviving proportion 0.55
# repeats 115	total mated 134	surviving gene pool 3
# oldest survivor 10	Ultimate fucker 34	total mutants 1
#
# EPOCH: 72	epoch time 8 seconds
# surviving population 356	peak population 707	epoch peak 589	surviving proportion 0.60
# repeats 114	total mated 145	surviving gene pool 3
# oldest survivor 11	Ultimate fucker 36	total mutants 1
#
# EPOCH: 73	epoch time 8 seconds
# surviving population 391	peak population 707	epoch peak 637	surviving proportion 0.61
# repeats 119	total mated 146	surviving gene pool 4
# oldest survivor 6	Ultimate fucker 20	total mutants 1
#
# EPOCH: 74	epoch time 9 seconds
# surviving population 445	peak population 707	epoch peak 707	surviving proportion 0.63
# repeats 118	total mated 162	surviving gene pool 4
# oldest survivor 5	Ultimate fucker 17	total mutants 1
#
# EPOCH: 75	epoch time 8 seconds
# surviving population 397	peak population 707	epoch peak 684	surviving proportion 0.58
# repeats 109	total mated 146	surviving gene pool 4
# oldest survivor 6	Ultimate fucker 19	total mutants 1
#
# EPOCH: 76	epoch time 8 seconds
# surviving population 399	peak population 707	epoch peak 637	surviving proportion 0.63
# repeats 108	total mated 154	surviving gene pool 5
# oldest survivor 7	Ultimate fucker 23	total mutants 4
#
# EPOCH: 77	epoch time 8 seconds
# surviving population 365	peak population 707	epoch peak 592	surviving proportion 0.62
# repeats 108	total mated 141	surviving gene pool 5
# oldest survivor 7	Ultimate fucker 25	total mutants 1
#
# EPOCH: 78	epoch time 8 seconds
# surviving population 431	peak population 707	epoch peak 663	surviving proportion 0.65
# repeats 114	total mated 160	surviving gene pool 5
# oldest survivor 8	Ultimate fucker 25	total mutants 0
#
# EPOCH: 79	epoch time 8 seconds
# surviving population 363	peak population 707	epoch peak 570	surviving proportion 0.64
# repeats 98	total mated 124	surviving gene pool 4
# oldest survivor 7	Ultimate fucker 28	total mutants 1
#
# EPOCH: 80	epoch time 9 seconds
# surviving population 426	peak population 707	epoch peak 670	surviving proportion 0.64
# repeats 115	total mated 157	surviving gene pool 5
# oldest survivor 8	Ultimate fucker 33	total mutants 1
#
# EPOCH: 81	epoch time 8 seconds
# surviving population 378	peak population 707	epoch peak 608	surviving proportion 0.62
# repeats 107	total mated 139	surviving gene pool 4
# oldest survivor 6	Ultimate fucker 27	total mutants 0
#
# EPOCH: 82	epoch time 8 seconds
# surviving population 355	peak population 707	epoch peak 599	surviving proportion 0.59
# repeats 106	total mated 135	surviving gene pool 5
# oldest survivor 6	Ultimate fucker 23	total mutants 2
#
# EPOCH: 83	epoch time 8 seconds
# surviving population 406	peak population 707	epoch peak 639	surviving proportion 0.64
# repeats 113	total mated 146	surviving gene pool 5
# oldest survivor 7	Ultimate fucker 21	total mutants 1
#
# EPOCH: 84	epoch time 8 seconds
# surviving population 334	peak population 707	epoch peak 541	surviving proportion 0.62
# repeats 104	total mated 130	surviving gene pool 4
# oldest survivor 7	Ultimate fucker 17	total mutants 0
#
# EPOCH: 85	epoch time 8 seconds
# surviving population 369	peak population 707	epoch peak 601	surviving proportion 0.61
# repeats 112	total mated 142	surviving gene pool 5
# oldest survivor 8	Ultimate fucker 20	total mutants 0
#
# EPOCH: 86	epoch time 9 seconds
# surviving population 480	peak population 725	epoch peak 725	surviving proportion 0.66
# repeats 122	total mated 176	surviving gene pool 7
# oldest survivor 6	Ultimate fucker 19	total mutants 2
#
# EPOCH: 87	epoch time 9 seconds
# surviving population 403	peak population 725	epoch peak 681	surviving proportion 0.59
# repeats 104	total mated 139	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 23	total mutants 4
#
# EPOCH: 88	epoch time 8 seconds
# surviving population 315	peak population 725	epoch peak 551	surviving proportion 0.57
# repeats 98	total mated 119	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 25	total mutants 2
#
# EPOCH: 89	epoch time 8 seconds
# surviving population 391	peak population 725	epoch peak 618	surviving proportion 0.63
# repeats 119	total mated 147	surviving gene pool 7
# oldest survivor 6	Ultimate fucker 28	total mutants 0
#
# EPOCH: 90	epoch time 8 seconds
# surviving population 325	peak population 725	epoch peak 549	surviving proportion 0.59
# repeats 113	total mated 131	surviving gene pool 9
# oldest survivor 4	Ultimate fucker 12	total mutants 2
#
# EPOCH: 91	epoch time 9 seconds
# surviving population 369	peak population 725	epoch peak 599	surviving proportion 0.62
# repeats 107	total mated 139	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 16	total mutants 1
#
# EPOCH: 92	epoch time 9 seconds
# surviving population 360	peak population 725	epoch peak 624	surviving proportion 0.58
# repeats 109	total mated 136	surviving gene pool 6
# oldest survivor 5	Ultimate fucker 16	total mutants 2
#
# EPOCH: 93	epoch time 9 seconds
# surviving population 424	peak population 725	epoch peak 675	surviving proportion 0.63
# repeats 122	total mated 155	surviving gene pool 6
# oldest survivor 6	Ultimate fucker 23	total mutants 1
#
# EPOCH: 94	epoch time 8 seconds
# surviving population 390	peak population 725	epoch peak 616	surviving proportion 0.63
# repeats 109	total mated 151	surviving gene pool 6
# oldest survivor 7	Ultimate fucker 26	total mutants 0
#
# EPOCH: 95	epoch time 8 seconds
# surviving population 379	peak population 725	epoch peak 595	surviving proportion 0.64
# repeats 104	total mated 137	surviving gene pool 6
# oldest survivor 5	Ultimate fucker 32	total mutants 0
#
# EPOCH: 96	epoch time 9 seconds
# surviving population 346	peak population 725	epoch peak 592	surviving proportion 0.58
# repeats 104	total mated 127	surviving gene pool 8
# oldest survivor 5	Ultimate fucker 19	total mutants 3
#
# EPOCH: 97	epoch time 9 seconds
# surviving population 437	peak population 725	epoch peak 709	surviving proportion 0.62
# repeats 121	total mated 160	surviving gene pool 8
# oldest survivor 6	Ultimate fucker 22	total mutants 4
#
# EPOCH: 98	epoch time 8 seconds
# surviving population 385	peak population 725	epoch peak 598	surviving proportion 0.64
# repeats 107	total mated 140	surviving gene pool 7
# oldest survivor 6	Ultimate fucker 19	total mutants 3
#
# EPOCH: 99	epoch time 8 seconds
# surviving population 386	peak population 725	epoch peak 639	surviving proportion 0.60
# repeats 101	total mated 139	surviving gene pool 9
# oldest survivor 7	Ultimate fucker 21	total mutants 3
#
# EPOCH: 100	epoch time 9 seconds
# surviving population 363	peak population 725	epoch peak 595	surviving proportion 0.61
# repeats 106	total mated 130	surviving gene pool 8
# oldest survivor 4	Ultimate fucker 23	total mutants 1

# %%
blobland.animate_epoch(98)
